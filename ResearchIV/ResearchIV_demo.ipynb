# %% [markdown]
# # ResearchIV Demo\n
# \n
# IV-RV 研究最小示例：运行研究、查看指标、查看机会表。

# %%
from Modules import run_research

# %%
result = run_research('modules/config.yaml')
result['metrics']
# Out:
# Error: HTTPConnectionPool(host='127.0.0.1', port=10808): Max retries exceeded with url: http://58.49.210.250:9999//get_product (Caused by ProxyError('Unable to connect to proxy', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None)))
# Retrying after 3 second... (Attempt 1/3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 result = run_research('modules/config.yaml')
#       2 result['metrics']
#
# File c:\Users\21927\trading\Backtest\ResearchIV\modules\__init__.py:15, in run_research(config_path)
#      13 def run_research(config_path: str):
#      14     engine_mod = _reload_runtime_module()
# ---> 15     return engine_mod.run_research(config_path)
#
# File c:\Users\21927\trading\Backtest\ResearchIV\modules\ivrv_engine.py:356, in run_research(config_path)
#     354 cfg = load_config(config_path)
# ...

# %%
result['opportunities'].tail(20)

# %%
result['analysis']
