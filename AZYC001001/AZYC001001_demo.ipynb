# %% [markdown]
# # AZYC001001 Backtest Demo
# Run the strategy and inspect metrics/artifacts.

# %%
from modules import run_backtest
result = run_backtest('Modules/config.yaml')
result['metrics']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from modules import run_backtest
# ----> 2 result = run_backtest('Modules/config.yaml')
#       3 result['metrics']
#
# File c:\Users\21927\trading\Backtest\AZYC001001\modules\__init__.py:23, in run_backtest(config_path)
#      21 def run_backtest(config_path: str):
#      22     backtest_mod, _ = _reload_runtime_modules()
# ---> 23     return backtest_mod.run_backtest(config_path)
#
# File c:\Users\21927\trading\Backtest\AZYC001001\modules\backtest_engine.py:661, in run_backtest(config_path)
#     659 if not output_dir.is_absolute():
#     660     config_dir = Path(cfg.get("_config_dir", "."))
# --> 661     output_dir = (config_dir / output_dir).resolve()
#     663 save_results(output_dir, frames)
#     664 analysis = analyze(
#     665     output_dir,
#     666     initial_capital=float(cfg["initial_capital"]),
#     667     risk_free_rate=float(cfg.get("risk_free_rate", 0.0)),
#     668 )
#
# File c:\Users\21927\anaconda3\envs\my_env_trading\Lib\pathlib.py:1240, in Path.resolve(self, strict)
#    1237         raise RuntimeError("Symlink loop from %r" % e.filename)
#    1239 try:
# -> 1240     s = self._flavour.realpath(self, strict=strict)
#    1241 except OSError as e:
#    1242     check_eloop(e)
#
# File <frozen ntpath>:727, in realpath(path, strict)
#
# KeyboardInterrupt:

# %%
from modules.analyze import analyze 
analysis = analyze(result['artifacts_path'])
analysis['metrics']
# Out:
#    initial_capital  total_pnl  total_return  benchmark_return  excess_return  \
# 0        1000000.0    78132.0      0.078132          0.578008      -0.499876
#
#    excess_pnl  annual_return_simple  annual_volatility    sharpe   sortino  \
# 0 -499876.098              0.081026           0.127582  0.635086  0.365372
#
#    ...  put_sell_count  call_sell_count  assignment_count  call_away_count  \
# 0  ...              13                0                 0                0
#
#    cycle_count_closed  cycle_count_open  win_rate_cycle  avg_cycle_days  \
# 0                  12                 1             1.0       28.967882
#
#    day_win_rate  profit_factor_day
# 0      0.670782           1.352281
#
# [1 rows x 27 columns]
